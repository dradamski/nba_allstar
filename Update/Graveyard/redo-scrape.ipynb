# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import urllib.request

# %% [markdown]
# Get links to every team's page

# %%
# %%time
def get_teams(soup):
    '''Takes BeautifulSoup object of NBA teams page and returns
       list of links to team pages.'''
   
    for link in soup.find_all('a'):
        team = link.text
        if 'teams' in link.get('href'):
            yield link.get('href')
        if team == 'Washington Wizards':
            break

site = 'https://www.basketball-reference.com/teams/'
page= urllib.request.urlopen(site)
soup = BeautifulSoup(page, 'lxml')

teamlinks = tuple(get_teams(soup))[1:]
# Out:
# CPU times: user 77.1 ms, sys: 4.1 ms, total: 81.2 ms
# Wall time: 1.16 s

# %% [markdown]
# From teamlinks, get every rostered player in league.

# %%
# %%time
def get_players(teams, year):
    '''From list of teams, get list of all players on that 
       team for a given year. This is only set up to work
       on seasons from 2009-10 on. There may be errors going
       further back.'''
    
    year = str(year)
    
    for team in teams:
        link = 'https://www.basketball-reference.com' + team + year + '.html'
        if 'NJN' in link:
            if year > '2012':
                link = 'https://www.basketball-reference.com/teams/BRK/' + year + '.html'
            else:
                link = 'https://www.basketball-reference.com/teams/NJN/' + year + '.html'
        if 'CHA' in link:
                if year > '2014':
                    link = 'https://www.basketball-reference.com/teams/CHO/' + year + '.html'
                elif year < '2003':
                    link = 'https://www.basketball-reference.com/teams/CHH/' + year + '.html'
                else:
                    'https://www.basketball-reference.com/teams/CHA/'+ year + '.html'
                
        if 'NOH' in link:
            if year > '2013':
                link = 'https://www.basketball-reference.com/teams/NOP/' + year + '.html'
            else:
                 link = 'https://www.basketball-reference.com/teams/NOH/' + year + '.html'
               
        page = urllib.request.urlopen(link)
        soup = BeautifulSoup(page, 'lxml')

        for i in soup.find_all('table')[0].find_all('a'):
            if 'players' in i['href']:
                yield (i.text, i['href'])
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs

# %%
# %%timeit
player_set = set()
for year in range(2010,2020):
    new_set = set(get_players(teamlinks, year))
    if len(player_set) == 0:
        player_set = new_set
    else:
        player_set.update(new_set)
    print(year, len(player_set))
# Out:
# 2010 442
# 2011 523
# 2012 611
# 2013 692
# 2014 770
# 2015 852
# 2016 926
# 2017 1014
# 2018 1133
# 2019 1238
# CPU times: user 23.8 s, sys: 1.99 s, total: 25.8 s
# Wall time: 15min 40s

# %% [markdown]
# Get stats for the last season for each player

# %%
def get_stats(player_set, start_year):
    """Takes a set of players and pulls their stats """
    
    for player in player_set:
        reference_site = 'https://www.basketball-reference.com' + player[1]
        page = urllib.request.urlopen(reference_site)
        soup = BeautifulSoup(page, 'lxml')
        per_game_table = soup.table

        # Excludes rookies from the table
        if per_game_table != None:
            raw_height = str(soup.find_all('div', {'id':'info'})[0].find_all('span', {'itemprop':'height'})[0].string)
            height_tup = raw_height.split('-')
            height = int(height_tup[0])*12 + int(height_tup[1])
            player_df = pd.read_html(reference_site)[0]
            player_df['Height'] = height
            player_df['href'] = player[1]
            player_df['Player'] = player[0]

            # removes career totals
            player_df = player_df[player_df.Season != 'Career']
            # removes seasons where players did not play
            player_df = player_df[player_df.Tm != player_df.Lg]
            # remove totals for each team player played on
            player_df = player_df[player_df.Age.notna()]
            # trim season stat to be the starting year
            player_df = player_df.Season.str[:4]
            # removes seasons before 2009-10
            player_df = player_df[player_df['Season'] > '2008']
            all_season_df = all_season_df.append(player_df)
            if x % 50:
                print(x, player_df.Player.unique())
            x += 1

# %%
# %%time
all_season_df = pd.DataFrame()
x=1
for player in player_set:
    reference_site = 'https://www.basketball-reference.com' + player[1]
    page = urllib.request.urlopen(reference_site)
    soup = BeautifulSoup(page, 'lxml')
    per_game_table = soup.table
    
    # Excludes rookies from the table
    if per_game_table != None:
        height = str(soup.find_all('div', {'id':'info'})[0].find_all('span', {'itemprop':'height'})[0].string)
        height = height.split('-')
        height = int(height[0])*12 + int(height[1])
        player_df = pd.read_html(reference_site)[0]
        player_df['Height'] = height
        player_df['href'] = player[1]
        player_df['Player'] = player[0]
        # removes career totals
        player_df = player_df[player_df.Season != 'Career']
        # removes seasons where players did not play
        player_df = player_df[player_df.Tm != player_df.Lg]
        # remove totals for each team player played on
        player_df = player_df[player_df.Age.notna()]
        # trim season stat to be the starting year
        player_df['Season'] = player_df.Season.str[:4]
        # removes seasons before 2009-10
        player_df = player_df[player_df['Season'] > '2008']
        all_season_df = all_season_df.append(player_df)
        x += 1
# Out:
# 1 ['Isaiah Taylor']
# 2 ['Frank Jackson']
# 3 ['Oleksiy Pecherov']
# 4 ['Maxi Kleber']
# 5 ['Steven Adams']
# 6 ['Sasha Kaun']
# 7 ['Grant Jerrett']
# 8 ['Johan Petro']
# 9 ['Deron Williams']
# 10 ['Ed Davis']
# 11 ['Andre Drummond']
# 12 ['Marc Gasol']
# 13 ['Joe Young']
# 14 ['Tahjere McCall']
# 15 ['D.J. White']
# 16 ['Shai Gilgeous-Alexander']
# 17 ['Tim Frazier']
# 18 ['Mirza Teletović']
# 19 ['Nenad Krstić']
# 20 ['Sherron Collins']
# 21 ['Zhaire Smith']
# 22 ['Tyler Davis']
# 23 ['Ersan İlyasova']
# 24 ['Earl Boykins']
# 25 ['Allen Crabbe']
# 26 ['Gary Payton']
# 27 ['Juan Hernangómez']
# 28 ['Willie Reed']
# 29 ["De'Aaron Fox"]
# 30 ['DeShawn Stevenson']
# 31 ['Larry Owens']
# 32 ['Austin Daye']
# 33 ['Antoine Wright']
# 34 ['Jae Crowder']
# 35 ['Kay Felder']
# 36 ['Christian Wood']
# 37 ['Keita Bates-Diop']
# 38 ['Mickaël Gelabale']
# 39 ['Marvin Williams']
# 40 ['Derrick Rose']
# 41 ['Will Bynum']
# 42 ['Tyus Jones']
# 43 ['Raul Neto']
# 44 ['Lauri Markkanen']
# 45 ['Andrés Nocioni']
# 46 ['Vernon Macklin']
# 47 ['Derrick Brown']
# 48 ['Matthew Dellavedova']
# 49 ['James Johnson']
# 51 ['Rashad Vaughn']
# 52 ["Patrick O'Bryant"]
# 53 ['Tyrus Thomas']
# 54 ['T.J. Leaf']
# 55 ['Semi Ojeleye']
# 56 ['Tony Snell']
# 57 ["Toure' Murry"]
# 58 ['Craig Brackins']
# 59 ['Chris Wright']
# 60 ['Julyan Stone']
# 61 ['Dominic McGuire']
# 62 ['Chris Smith']
# 63 ['Drew Gordon']
# 64 ['Isaiah Canaan']
# 65 ['Timothé Luwawu-Cabarrot']
# 66 ['Marshall Plumlee']
# 67 ['Patricio Garino']
# 68 ['Tim Quarterman']
# 69 ['Mike James']
# 70 ['Larry Hughes']
# 71 ['Terrance Ferguson']
# 72 ['Donté Greene']
# 73 ['Danilo Gallinari']
# 74 ['Alec Burks']
# 75 ['Jerrelle Benimon']
# 76 ['Paul Davis']
# 77 ['Jason Maxiell']
# 78 ['Steve Novak']
# 79 ['Devin Ebanks']
# 80 ['Josh Smith']
# 81 ['Brandon Rush']
# 82 ['Malik Hairston']
# 83 ['Trey McKinney-Jones']
# 84 ['Jimmy Butler']
# 85 ['Tyler Lydon']
# 86 ['Maurice Ndour']
# 87 ['Cole Aldrich']
# 88 ['Will Cherry']
# 89 ['Donovan Mitchell']
# 90 ['Lavoy Allen']
# 91 ['Rudy Gobert']
# 92 ['Brandon Goodwin']
# 93 ['Jonathan Bender']
# 94 ['Charlie Bell']
# 95 ['Mason Plumlee']
# 96 ['Victor Claver']
# 97 ['Yi Jianlian']
# 98 ['Robert Covington']
# 99 ['Isaiah Hicks']
# 101 ['Nenê Hilário']
# 102 ['Miloš Teodosić']
# 103 ['Chris Paul']
# 104 ['Nick Johnson']
# 105 ['Ante Žižić']
# 106 ['Mike Conley']
# 107 ['Eric Dawson']
# 108 ['Andrew Goudelock']
# 109 ['Dorell Wright']
# 110 ['Maurice Harkless']
# 111 ['Garret Siler']
# 112 ['Noah Vonleh']
# 113 ['Ron Baker']
# 114 ['Cory Higgins']
# 115 ['Jason Smith']
# 116 ['Daniel Theis']
# 117 ['Darko Miličić']
# 118 ["Hamady N'Diaye"]
# 119 ['Kyle Korver']
# 120 ['Andrew Bogut']
# 121 ['Dewayne Dedmon']
# 122 ['Duje Dukan']
# 123 ['Daniel Orton']
# 124 ['Dairis Bertāns']
# 125 ['Mardy Collins']
# 126 ['Hamed Haddadi']
# 127 ['Andrea Bargnani']
# 128 ['Grayson Allen']
# 129 ['Tristan Thompson']
# 130 ['John Henson']
# 131 ['Jordan Hamilton']
# 132 ['Axel Toupane']
# 133 ['Patrick Christopher']
# 134 ['Antonio McDyess']
# 135 ['Tyler Hansbrough']
# 136 ['Bernard James']
# 137 ['Shawn Long']
# 138 ['Chris Hunter']
# 139 ['Chris Wright']
# 140 ['Bojan Bogdanović']
# 141 ['Jayson Tatum']
# 142 ['Michael Kidd-Gilchrist']
# 143 ['Cartier Martin']
# 144 ['Mo Williams']
# 145 ['Francisco Elson']
# 146 ['Brian Cardinal']
# 147 ['Theo Ratliff']
# 148 ['Kirk Hinrich']
# 149 ['Anfernee Simons']
# 151 ['Jacob Evans']
# 152 ['Victor Oladipo']
# 153 ['DeAndre Jordan']
# 154 ['Bobby Portis']
# 155 ['Eric Maynor']
# 156 ['Henry Ellenson']
# 157 ['Jacob Pullen']
# 158 ['Acie Law']
# 159 ['Shayne Whittington']
# 160 ['Dario Šarić']
# 161 ['Jeff Foote']
# 162 ['Malcolm Miller']
# 163 ['Roy Hibbert']
# 164 ['Jared Terrell']
# 165 ['Justin Harper']
# 166 ['Scott Machado']
# 167 ['Furkan Aldemir']
# 168 ['Al Horford']
# 169 ['Darington Hobson']
# 170 ['Lazar Hayward']
# 171 ['Devyn Marble']
# 172 ['Brook Lopez']
# 173 ['Cheick Diallo']
# 174 ['Marcus Georges-Hunt']
# 175 ['Andrei Kirilenko']
# 176 ['Caron Butler']
# 177 ['Jordan Williams']
# 178 ['Jason Kidd']
# 179 ['Joakim Noah']
# 180 ['Rodrigue Beaubois']
# 181 ['Jan Veselý']
# 182 ['Rodney McGruder']
# 183 ['Mangok Mathiang']
# 184 ['Alfonzo McKinnie']
# 185 ['Raja Bell']
# 186 ['Sasha Vujačić']
# 187 ['Caris LeVert']
# 188 ['JamesOn Curry']
# 189 ['Josh Davis']
# 190 ['Rashard Lewis']
# 191 ['Malcolm Brogdon']
# 192 ['DeMarre Carroll']
# 193 ['Travis Wear']
# 194 ['Kenrich Williams']
# 195 ['Derrick Walton']
# 196 ['Darius Morris']
# 197 ['Morris Peterson']
# 198 ['Ray Allen']
# 199 ['Jahlil Okafor']
# 201 ["Royce O'Neale"]
# 202 ['Courtney Fortson']
# 203 ['Rawle Alkins']
# 204 ['Deng Adel']
# 205 ['Semaj Christon']
# 206 ['Lindsey Hunter']
# 207 ['Xavier Henry']
# 208 ['Furkan Korkmaz']
# 209 ['London Perrantes']
# 210 ['Eric Moreland']
# 211 ['Donte DiVincenzo']
# 212 ['Greg Oden']
# 213 ['Cedi Osman']
# 214 ['Trey Johnson']
# 215 ['Mike Wilks']
# 216 ['Antonio Blakeney']
# 217 ['Zoran Dragić']
# 218 ['Sasha Pavlović']
# 219 ['Mario Chalmers']
# 220 ['Tobias Harris']
# 221 ['Ben Hansbrough']
# 222 ['Tyler Zeller']
# 223 ['Brandon Sampson']
# 224 ['Marcus Paige']
# 225 ['Alex Caruso']
# 226 ['Ricky Ledo']
# 227 ['Thomas Robinson']
# 228 ['Damian Jones']
# 229 ['Brice Johnson']
# 230 ['Montrezl Harrell']
# 231 ['James Southerland']
# 232 ['Andre Iguodala']
# 233 ['Adam Morrison']
# 234 ['Andrew Nicholson']
# 235 ['Will Barton']
# 236 ['Tim Hardaway']
# 237 ['Gary Forbes']
# 238 ['Cleanthony Early']
# 239 ['Gerald Henderson']
# 240 ['Chris McCullough']
# 241 ['Jordan Hill']
# 242 ['Terry Rozier']
# 243 ['Mindaugas Kuzminskas']
# 244 ['Chris Duhon']
# 245 ['Al Harrington']
# 246 ['Marcus Thornton']
# 247 ['Jeff Foster']
# 248 ['Isaiah Whitehead']
# 249 ['Taj Gibson']
# 251 ['Martell Webster']
# 252 ['DaJuan Summers']
# 253 ['Malcolm Thomas']
# 254 ['Eric Bledsoe']
# 255 ['Paul Zipser']
# 256 ['Daniel Hamilton']
# 257 ['Willie Green']
# 258 ['Thomas Bryant']
# 259 ['Gary Clark']
# 260 ['Jordan Clarkson']
# 261 ['Jeremy Evans']
# 262 ['Frank Ntilikina']
# 263 ['Markel Brown']
# 264 ['Juwan Howard']
# 265 ['Jalen Jones']
# 266 ['Mickell Gladness']
# 267 ['Aaron Brooks']
# 268 ['Allen Iverson']
# 269 ['James Posey']
# 270 ['Sergio Rodríguez']
# 271 ['Vladimir Radmanović']
# 272 ['Nazr Mohammed']
# 273 ['Anthony Bennett']
# 274 ['Julian Washburn']
# 275 ['Kevin Séraphin']
# 276 ['Shaun Livingston']
# 277 ['Nick Young']
# 278 ['Carldell Johnson']
# 279 ['Devin Booker']
# 280 ['Marcus Landry']
# 281 ['Nate Robinson']
# 282 ['Glen Davis']
# 283 ['Kyle Collinsworth']
# 284 ['Jamel Artis']
# 285 ['Jaylen Brown']
# 286 ['Festus Ezeli']
# 287 ['Jared Dudley']
# 288 ['Ronnie Price']
# 289 ['Khyri Thomas']
# 290 ['Joe Alexander']
# 291 ['Brandon Bass']
# 292 ['Reggie Evans']
# 293 ['Dexter Pittman']
# 294 ['O.J. Mayo']
# 295 ['Keith Benson']
# 296 ['Marquese Chriss']
# 297 ['Jaron Blossomgame']
# 298 ['Tim Thomas']
# 299 ['B.J. Johnson']
# 301 ['Frank Kaminsky']
# 302 ['Anthony Tolliver']
# 303 ['DeMarcus Cousins']
# 304 ['Collin Sexton']
# 305 ['Isaac Humphries']
# 306 ['Damian Lillard']
# 307 ['Tony Battie']
# 308 ['JaJuan Johnson']
# 309 ['Orien Greene']
# 310 ['Luke Walton']
# 311 ['Wilson Chandler']
# 312 ['Hollis Thompson']
# 313 ['David Nwaba']
# 314 ['Skal Labissière']
# 315 ['Justin Hamilton']
# 316 ['Otto Porter']
# 317 ['Cody Zeller']
# 318 ['DeVaughn Akoon-Purcell']
# 319 ['Kenyon Martin']
# 320 ['Solomon Jones']
# 321 ['Jordan Loyd']
# 322 ['Manu Ginóbili']
# 323 ['Tony Mitchell']
# 324 ['Miles Plumlee']
# 325 ['Adonis Thomas']
# 326 ['Brandon Jennings']
# 327 ['Darrell Arthur']
# 328 ['Eugene Jeter']
# 329 ['Andrew Bynum']
# 330 ['Stephen Jackson']
# 331 ['Matt Barnes']
# 332 ['Ty Lawson']
# 333 ['Dahntay Jones']
# 334 ['Jodie Meeks']
# 335 ['Jordan McRae']
# 336 ['Brad Wanamaker']
# 337 ['Harry Giles']
# 338 ['Sebastian Telfair']
# 339 ['Carlos Arroyo']
# 340 ['Tim Duncan']
# 341 ['Jaylen Morris']
# 342 ['Donte Grantham']
# 343 ['Kelenna Azubuike']
# 344 ['Omri Casspi']
# 345 ['A.J. Price']
# 346 ['CJ McCollum']
# 347 ['Deandre Ayton']
# 348 ['Justin Jackson']
# 349 ['Pablo Prigioni']
# 351 ['Jerry Stackhouse']
# 352 ['Aaron Gray']
# 353 ['Sergey Karasev']
# 354 ['Harrison Barnes']
# 355 ['Jannero Pargo']
# 356 ['Kevin Love']
# 357 ['Wade Baldwin']
# 358 ['Dennis Smith']
# 359 ['Zydrunas Ilgauskas']
# 360 ['Gal Mekel']
# 361 ['Edy Tavares']
# 362 ['Earl Clark']
# 363 ['Ryan Gomes']
# 364 ['Sean May']
# 365 ['Demetrius Jackson']
# 366 ["De'Anthony Melton"]
# 367 ['Denzel Valentine']
# 368 ['Josh Harrellson']
# 369 ['Reggie Bullock']
# 370 ['Mitch Creek']
# 371 ['Leandro Barbosa']
# 372 ['Orlando Johnson']
# 373 ['Jerome Jordan']
# 374 ['David Andersen']
# 375 ['Paul Millsap']
# 376 ['Michael Finley']
# 377 ['Patrick Beverley']
# 378 ['Dāvis Bertāns']
# 379 ['Keith Bogans']
# 380 ['Maalik Wayns']
# 381 ['LaMarcus Aldridge']
# 382 ['K.J. McDaniels']
# 383 ['Chris Boucher']
# 384 ['Ricky Rubio']
# 385 ['Jermaine Taylor']
# 386 ['Jared Sullinger']
# 387 ['Jeremy Lamb']
# 388 ['Mike Bibby']
# 389 ['Dwayne Jones']
# 390 ['Edwin Ubiles']
# 391 ['Lance Stephenson']
# 392 ['Jerel McNeal']
# 393 ['Bam Adebayo']
# 394 ['Matt Costello']
# 395 ['Henry Walker']
# 396 ['Kristaps Porziņģis']
# 397 ['Chris Kaman']
# 398 ['Mike Scott']
# 399 ['Spencer Dinwiddie']
# 401 ['Trenton Hassell']
# 402 ['Karl-Anthony Towns']
# 403 ['Mitchell Robinson']
# 404 ['Khem Birch']
# 405 ['Coby Karl']
# 406 ['James Anderson']
# 407 ['Nemanja Nedović']
# 408 ['Royce White']
# 409 ['Tomáš Satoranský']
# 410 ['Channing Frye']
# 411 ['Joel Embiid']
# 412 ['Johnathan Williams']
# 413 ['Jorge Gutiérrez']
# 414 ['Trae Young']
# 415 ['Rodney Carney']
# 416 ['Jamil Wilson']
# 417 ['Jeremy Lin']
# 418 ['Melvin Frazier']
# 419 ['Sonny Weems']
# 420 ['Kevon Looney']
# 421 ['Gerald Wallace']
# 422 ['Yogi Ferrell']
# 423 ['Xavier Silas']
# 424 ['Draymond Green']
# 425 ['Sviatoslav Mykhailiuk']
# 426 ['Tyshawn Taylor']
# 427 ['Nigel Hayes']
# 428 ['Ben Gordon']
# 429 ['Pops Mensah-Bonsu']
# 430 ['Thabo Sefolosha']
# 431 ['Andre Emmett']
# 432 ['Primož Brezec']
# 433 ['Billy Garrett']
# 434 ['Yakhouba Diawara']
# 435 ['Ben Wallace']
# 436 ['Patrick McCaw']
# 437 ['DeJuan Blair']
# 438 ['Andray Blatche']
# 439 ['Spencer Hawes']
# 440 ['Derrick Byars']
# 441 ['Shake Milton']
# 442 ['Marcus Williams']
# 443 ['Arron Afflalo']
# 444 ['Goran Dragić']
# 445 ['T.J. Ford']
# 446 ['Tony Mitchell']
# 447 ['Miles Bridges']
# 448 ['Trevor Booker']
# 449 ['Francisco García']
# 451 ['Chauncey Billups']
# 452 ['Joey Graham']
# 453 ['Jrue Holiday']
# 454 ['Mehmet Okur']
# 455 ['Cristiano Felício']
# 456 ['Jonathan Isaac']
# 457 ['Samardo Samuels']
# 458 ['DeQuan Jones']
# 459 ['Kris Dunn']
# 460 ['Doron Lamb']
# 461 ['Ivica Zubac']
# 462 ['Emeka Okafor']
# 463 ['Vince Edwards']
# 464 ['Jaren Jackson']
# 465 ['Miroslav Raduljica']
# 466 ['Terrel Harris']
# 467 ['Drew Eubanks']
# 468 ['Patrick Ewing']
# 469 ['Chris Singleton']
# 470 ['Reggie Hearn']
# 471 ['Wesley Johnson']
# 472 ['Kevin Garnett']
# 473 ['Shannon Brown']
# 474 ['Mustafa Shakur']
# 475 ['Joe Johnson']
# 476 ['Kenneth Faried']
# 477 ['Cliff Alexander']
# 478 ['Wayne Selden']
# 479 ['Dorian Finney-Smith']
# 480 ['Landry Shamet']
# 481 ['Ime Udoka']
# 482 ['Yao Ming']
# 483 ['Ronny Turiaf']
# 484 ['Cameron Reynolds']
# 485 ['Luke Kennard']
# 486 ['Georges Niang']
# 487 ['Kelly Oubre']
# 488 ['Roko Ukić']
# 489 ['Steven Hunter']
# 490 ['Luke Kornet']
# 491 ['Amile Jefferson']
# 492 ['Chris Wilcox']
# 493 ['Bruce Brown']
# 494 ['Dejounte Murray']
# 495 ['Tyson Chandler']
# 496 ['Thaddeus Young']
# 497 ['Chris Chiozza']
# 498 ['Marreese Speights']
# 499 ['Andre Roberson']
# 501 ['Darius Songaila']
# 502 ['Jeremy Pargo']
# 503 ['Russ Smith']
# 504 ['Luther Head']
# 505 ['Tyler Ennis']
# 506 ['Troy Brown']
# 507 ['Viacheslav Kravtsov']
# 508 ['Devean George']
# 509 ['Jimmer Fredette']
# 510 ['Reggie Williams']
# 511 ['Lester Hudson']
# 512 ['Shabazz Muhammad']
# 513 ['Nick Calathes']
# 514 ['Shavlik Randolph']
# 515 ['Charles Jenkins']
# 516 ['Shawn Marion']
# 517 ['Justin Holiday']
# 518 ['Matt Carroll']
# 519 ['Randy Foye']
# 520 ['Rodney Hood']
# 521 ['Anthony Davis']
# 522 ['Elfrid Payton']
# 523 ['Devin Robinson']
# 524 ['Zach LaVine']
# 525 ['Melvin Ely']
# 526 ['Adreian Payne']
# 527 ['Damion Lee']
# 528 ['Daequan Cook']
# 529 ['Jarred Vanderbilt']
# 530 ['Chris Richard']
# 531 ['Duncan Robinson']
# 532 ['Timofey Mozgov']
# 533 ['Gorgui Dieng']
# 534 ['Jonathan Gibson']
# 535 ['Bobby Brown']
# 536 ['Sundiata Gaines']
# 537 ['J.P. Macura']
# 538 ['Anthony Carter']
# 539 ['Alexey Shved']
# 540 ['Baron Davis']
# 541 ['Džanan Musa']
# 542 ['Jonas Jerebko']
# 543 ['Tony Bradley']
# 544 ['Steve Blake']
# 545 ['Dillon Brooks']
# 546 ['Marcus Haislip']
# 547 ['Jeff Teague']
# 548 ['Julius Randle']
# 549 ['Jonah Bolden']
# 551 ['Carmelo Anthony']
# 552 ["D'Angelo Russell"]
# 553 ['Monte Morris']
# 554 ['Marquis Daniels']
# 555 ['Abdel Nader']
# 556 ['Dwight Howard']
# 557 ['Deyonta Davis']
# 558 ['Ognjen Kuzmić']
# 559 ['Vítor Faverani']
# 560 ['Zabian Dowdell']
# 561 ['Donald Sloan']
# 562 ['Nikola Mirotić']
# 563 ['Lou Williams']
# 564 ['Yante Maten']
# 565 ['Kevin Murphy']
# 566 ['Nicolás Brussino']
# 567 ['Milton Doyle']
# 568 ['Josh Powell']
# 569 ['Maurice Evans']
# 570 ['Derrick Favors']
# 571 ['Haywood Highsmith']
# 572 ['Joel Przybilla']
# 573 ['Luke Ridnour']
# 574 ['Alex Stepheson']
# 575 ['Damjan Rudež']
# 576 ['Austin Rivers']
# 577 ['Klay Thompson']
# 578 ['Thomas Welsh']
# 579 ['Stephen Curry']
# 580 ['Allonzo Trier']
# 581 ['John Salmons']
# 582 ['Tyreke Evans']
# 583 ['Rondae Hollis-Jefferson']
# 584 ['Evan Fournier']
# 585 ['Marquis Teague']
# 586 ['C.J. Miles']
# 587 ['Alize Johnson']
# 588 ['Chandler Hutchison']
# 589 ['Jarvis Varnado']
# 590 ['Isaiah Thomas']
# 591 ['MarShon Brooks']
# 592 ['Alan Williams']
# 593 ['Kobe Bryant']
# 594 ['Zach Lofton']
# 595 ['Zach Randolph']
# 596 ['David Stockton']
# 597 ['Tibor Pleiß']
# 598 ['Ben Simmons']
# 599 ['Charlie Villanueva']
# 601 ['Larry Drew']
# 602 ['Armon Johnson']
# 603 ['Lance Thomas']
# 604 ['Dwight Powell']
# 605 ['Quincy Miller']
# 606 ['George King']
# 607 ['Solomon Hill']
# 608 ['Doug McDermott']
# 609 ['Brandon Roy']
# 610 ['Mike James']
# 611 ['Dragan Bender']
# 612 ['Stanley Johnson']
# 613 ['Mario Hezonja']
# 614 ['Fred VanVleet']
# 615 ['Zaza Pachulia']
# 616 ['Bryn Forbes']
# 617 ['Damion James']
# 618 ['Antonio Anderson']
# 619 ['Josh Howard']
# 620 ['Matt Bonner']
# 621 ['Quincy Pondexter']
# 622 ['Robert Williams']
# 623 ['Mike Tobey']
# 624 ['Vince Carter']
# 625 ['Jameel Warney']
# 626 ['Branden Dawson']
# 627 ['Antonio Daniels']
# 628 ['Daniel Ochefu']
# 629 ['PJ Dozier']
# 630 ['Eric Gordon']
# 631 ['Patty Mills']
# 632 ['Derrick White']
# 633 ['R.J. Hunter']
# 634 ['Troy Murphy']
# 635 ['Gani Lawal']
# 636 ['Richaun Holmes']
# 637 ['Brandon Paul']
# 638 ['Darius Johnson-Odom']
# 639 ['Tony Allen']
# 640 ['Jonny Flynn']
# 641 ['Greg Stiemsma']
# 642 ['Chuck Hayes']
# 643 ['Craig Smith']
# 644 ['Rodions Kurucs']
# 645 ['Manny Harris']
# 646 ['David West']
# 647 ['Rajon Rondo']
# 648 ['Alex Kirk']
# 649 ['Nemanja Bjelica']
# 651 ['Ish Smith']
# 652 ['Pascal Siakam']
# 653 ['Kyle Kuzma']
# 654 ['Travis Leslie']
# 655 ['Norman Powell']
# 656 ['Lamar Odom']
# 657 ['Byron Mullens']
# 658 ['Joe Chealey']
# 659 ['Darryl Watkins']
# 660 ['Alan Anderson']
# 661 ['Dwayne Bacon']
# 662 ['Larry Nance']
# 663 ['Henry Sims']
# 664 ['Kevin Huerter']
# 665 ['Shelden Williams']
# 666 ['D.J. Stephens']
# 667 ['Erik Murphy']
# 668 ['Metta World Peace']
# 669 ['Lamar Patterson']
# 670 ['Andy Rautins']
# 671 ['Ian Clark']
# 672 ['Jerry Smith']
# 673 ['Bobby Simmons']
# 674 ['Cameron Bairstow']
# 675 ['Buddy Hield']
# 676 ['JaVale McGee']
# 677 ['Marco Belinelli']
# 678 ['Rasheed Wallace']
# 679 ['Von Wafer']
# 680 ['Brandon Knight']
# 681 ['Michael Carter-Williams']
# 682 ['Jason Collins']
# 683 ['Andre Miller']
# 684 ['Desmond Mason']
# 685 ["Jermaine O'Neal"]
# 686 ['Delon Wright']
# 687 ['Delonte West']
# 688 ['Derek Fisher']
# 689 ['Hedo Türkoğlu']
# 690 ['Kostas Papanikolaou']
# 691 ['Chris Bosh']
# 692 ['Andris Biedriņš']
# 693 ['Aron Baynes']
# 694 ['Jeff Green']
# 695 ['Raymond Felton']
# 696 ['Rudy Gay']
# 697 ['Josh Richardson']
# 698 ['Jamario Moon']
# 699 ['Tyler Ulis']
# 701 ['Anthony Randolph']
# 702 ['Dante Cunningham']
# 703 ['Nicolás Laprovíttola']
# 704 ['Jacob Wiley']
# 705 ['Jonathon Simmons']
# 706 ['Solomon Alabi']
# 707 ['Jared Cunningham']
# 708 ['Greivis Vásquez']
# 709 ['Joel Anthony']
# 710 ['Dennis Schröder']
# 711 ['Tarik Black']
# 712 ['Daryl Macon']
# 713 ['Danny Green']
# 714 ['James White']
# 715 ['Ryan Broekhoff']
# 716 ['Josh Magette']
# 717 ['Coty Clarke']
# 718 ['Danny Granger']
# 719 ['Avery Bradley']
# 720 ['Trey Burke']
# 721 ['Ryan Bowen']
# 722 ['Tiago Splitter']
# 723 ['Jason Williams']
# 724 ['Naz Mitrou-Long']
# 725 ["Johnny O'Bryant"]
# 726 ['Taylor Griffin']
# 727 ['Alexis Ajinça']
# 728 ['Derrick Caracter']
# 729 ['Sean Marks']
# 730 ['Patrick Patterson']
# 731 ['Shane Larkin']
# 732 ['Kobi Simmons']
# 733 ['P.J. Hairston']
# 734 ['James Ennis']
# 735 ['Kelly Olynyk']
# 736 ['Anthony Morrow']
# 737 ['Treveon Graham']
# 738 ['Meyers Leonard']
# 739 ['Gordon Hayward']
# 740 ['Blake Ahearn']
# 741 ['Gilbert Arenas']
# 742 ['Mike Dunleavy']
# 743 ['James Young']
# 744 ['Joel Bolomboy']
# 745 ['Willie Warren']
# 746 ['Walt Lemon']
# 747 ['Ángel Delgado']
# 748 ['Alex Poythress']
# 749 ['Travis Diener']
# 751 ['Jerian Grant']
# 752 ['Ryan Arcidiacono']
# 753 ['Josh Gray']
# 754 ['Myke Henry']
# 755 ['Kendall Marshall']
# 756 ['Johnathan Motley']
# 757 ['Ronnie Brewer']
# 758 ['Jarvis Hayes']
# 759 ['Arnett Moultrie']
# 760 ['Lonzo Ball']
# 761 ['Leon Powe']
# 762 ['Beno Udrih']
# 763 ['Russell Westbrook']
# 764 ['Seth Curry']
# 765 ['Joe Harris']
# 766 ['Marcus Camby']
# 767 ['Courtney Lee']
# 768 ['Nerlens Noel']
# 769 ['Jakob Poeltl']
# 770 ['Marcin Gortat']
# 771 ['John Wall']
# 772 ['Chandler Parsons']
# 773 ['Ryan Reid']
# 774 ['Wendell Carter']
# 775 ['Wesley Matthews']
# 776 ['Jerryd Bayless']
# 777 ['Joe Smith']
# 778 ['Blake Griffin']
# 779 ['Josh Jackson']
# 780 ['Jarell Martin']
# 781 ['Earl Watson']
# 782 ['Hasheem Thabeet']
# 783 ['Isaiah Briscoe']
# 784 ['Kurt Thomas']
# 785 ['Jerome Robinson']
# 786 ['Elie Okobo']
# 787 ['Corey Maggette']
# 788 ['Cedric Jackson']
# 789 ['Derrick Williams']
# 790 ['Jamal Murray']
# 791 ['Will Conroy']
# 792 ['Kawhi Leonard']
# 793 ['Alex Len']
# 794 ['Erik McCree']
# 795 ['Brad Miller']
# 796 ['Bryce Cotton']
# 797 ['Darius Miller']
# 798 ['Jawun Evans']
# 799 ['Mike Harris']
# 801 ['Josh Boone']
# 802 ['Gerald Green']
# 803 ['Mario West']
# 804 ['Toney Douglas']
# 805 ['Mike Miller']
# 806 ['Ben Bentil']
# 807 ['David Wear']
# 808 ['Jarrett Allen']
# 809 ['T.J. Warren']
# 810 ['DeMar DeRozan']
# 811 ['Andrew Harrison']
# 812 ['Dirk Nowitzki']
# 813 ['Malik Beasley']
# 814 ['Tyler Cavanaugh']
# 815 ['Richard Hamilton']
# 816 ['Glen Rice']
# 817 ['Quinton Ross']
# 818 ['Khris Middleton']
# 819 ['Jemerrio Jones']
# 820 ['Larry Sanders']
# 821 ['Kendrick Perkins']
# 822 ['John Lucas III']
# 823 ['Royal Ivey']
# 824 ['Hakim Warrick']
# 825 ['Rasual Butler']
# 826 ['Ömer Aşık']
# 827 ['Brendan Haywood']
# 828 ['Yuta Watanabe']
# 829 ['Jamaal Tinsley']
# 830 ['Jeremy Tyler']
# 831 ['D.J. Augustin']
# 832 ['C.J. Williams']
# 833 ['Aaron Harrison']
# 834 ['Nathan Jawai']
# 835 ['Clint Capela']
# 836 ['Sterling Brown']
# 837 ['Gian Clavell']
# 838 ['Ronald Dupree']
# 839 ['Dakari Johnson']
# 840 ['Jabari Brown']
# 841 ['Tyler Dorsey']
# 842 ['James Michael McAdoo']
# 843 ['Damyean Dotson']
# 844 ['Darnell Jackson']
# 845 ['Damien Wilkins']
# 846 ['John Holland']
# 847 ['Luis Montero']
# 848 ['Dennis Horner']
# 849 ['Jason Thompson']
# 851 ['Josh Akognon']
# 852 ['Peja Stojaković']
# 853 ['Dan Gadzuric']
# 854 ['Brian Roberts']
# 855 ['David Lee']
# 856 ['Jeff Withey']
# 857 ['Jevon Carter']
# 858 ['Joey Dorsey']
# 859 ['Theo Pinson']
# 860 ['Semih Erden']
# 861 ['Chase Budinger']
# 862 ['Mickaël Piétrus']
# 863 ['Jonas Valančiūnas']
# 864 ['Nikola Vučević']
# 865 ['Marcus Smart']
# 866 ['Rudy Fernández']
# 867 ['Chimezie Metu']
# 868 ['Luke Harangody']
# 869 ['Eduardo Nájera']
# 870 ['Ike Diogu']
# 871 ['Enes Kanter']
# 872 ['Didier Ilunga-Mbenga']
# 873 ['Bismack Biyombo']
# 874 ['Jason Kapono']
# 875 ['Brandon Ingram']
# 876 ['John Jenkins']
# 877 ['Jarrod Uthoff']
# 878 ['Jordan Crawford']
# 879 ['Caleb Swanigan']
# 880 ['Ricky Davis']
# 881 ['Domantas Sabonis']
# 882 ['Deonte Burton']
# 883 ['Diamond Stone']
# 884 ['Jamal Crawford']
# 885 ['Josh McRoberts']
# 886 ['Malcolm Delaney']
# 887 ['Serge Ibaka']
# 888 ['Danuel House']
# 889 ['Chris Copeland']
# 890 ['Troy Williams']
# 891 ['Mikal Bridges']
# 892 ['Jordan Adams']
# 893 ['Moritz Wagner']
# 894 ['Emanuel Terry']
# 895 ['Aaron Holiday']
# 896 ['Michael Beasley']
# 897 ['Brian Scalabrine']
# 898 ['Ronald Murray']
# 899 ['Hassan Whiteside']
# 901 ['Jerami Grant']
# 902 ['J.J. Barea']
# 903 ['Chucky Atkins']
# 904 ['Richard Jefferson']
# 905 ['Scotty Hopson']
# 906 ['Tyrone Wallace']
# 907 ['Norris Cole']
# 908 ['Carlos Boozer']
# 909 ['Glenn Robinson']
# 910 ['Mohamed Bamba']
# 911 ['Shelvin Mack']
# 912 ['Giannis Antetokounmpo']
# 913 ['Rakeem Christmas']
# 914 ['Othyus Jeffers']
# 915 ['P.J. Tucker']
# 916 ['Jared Jeffries']
# 917 ['Rodney Purvis']
# 918 ['Troy Caupain']
# 919 ['Jarnell Stokes']
# 920 ['C.J. Watson']
# 921 ['Mitch McGary']
# 922 ['Jordan Bell']
# 923 ['Ray McCallum']
# 924 ["E'Twaun Moore"]
# 925 ['Marcelo Huertas']
# 926 ['Rafer Alston']
# 927 ['Joe Ingles']
# 928 ['Jusuf Nurkić']
# 929 ['Troy Daniels']
# 930 ['Erick Dampier']
# 931 ['Greg Smith']
# 932 ['Taurean Waller-Prince']
# 933 ['Frank Mason']
# 934 ['Jarrett Jack']
# 935 ["Kyle O'Quinn"]
# 936 ["Devonte' Graham"]
# 937 ['Trevor Ariza']
# 938 ['Brian Skinner']
# 939 ['Sheldon Mac']
# 940 ['Torrey Craig']
# 941 ['Earl Barron']
# 942 ['T.J. McConnell']
# 943 ['Malachi Richardson']
# 944 ['Sim Bhullar']
# 945 ['D.J. Kennedy']
# 946 ['Malcolm Lee']
# 947 ['Erick Green']
# 948 ['Justin Patton']
# 949 ['Jabari Parker']
# 951 ['Jeff Adrien']
# 952 ['Isaiah Hartenstein']
# 953 ['Zhou Qi']
# 954 ['Tayshaun Prince']
# 955 ['George Hill']
# 956 ['Vince Hunter']
# 957 ['Andrew Wiggins']
# 958 ['Dusty Hannahs']
# 959 ['Kevin Martin']
# 960 ['Etan Thomas']
# 961 ['Kemba Walker']
# 962 ['Carlos Delfino']
# 963 ['Davon Reed']
# 964 ['Kyle Anderson']
# 965 ['Ryan Anderson']
# 966 ['J.R. Smith']
# 967 ['Robin Lopez']
# 968 ['Al Thornton']
# 969 ['Phil Pressey']
# 970 ['Boban Marjanović']
# 971 ['Steve Nash']
# 972 ['D.J. Wilson']
# 973 ['Ray Spalding']
# 974 ['J.J. Hickson']
# 975 ['Marcus Banks']
# 976 ['José Calderón']
# 977 ['Kyrie Irving']
# 978 ['Boris Diaw']
# 979 ['Luis Scola']
# 980 ['Robert Sacre']
# 981 ['Matt Williams']
# 982 ['James Jones']
# 983 ['Xavier Munford']
# 984 ['Mychel Thompson']
# 985 ['Lonnie Walker']
# 986 ['Kyle Singler']
# 987 ['Josh Hart']
# 988 ['Josh Selby']
# 989 ['Jawad Williams']
# 990 ['Elijah Millsap']
# 991 ['Jason Terry']
# 992 ['Tornike Shengelia']
# 993 ['Roger Mason']
# 994 ['Jalen Brunson']
# 995 ['Jake Layman']
# 996 ['Archie Goodwin']
# 997 ['J.J. Redick']
# 998 ['Terrence Jones']
# 999 ["DeAndre' Bembry"]
# 1001 ['Dante Exum']
# 1002 ['Charles Cooke']
# 1003 ['Kyle Weaver']
# 1004 ['Casper Ware']
# 1005 ['Tim Ohlbrecht']
# 1006 ['Walker Russell']
# 1007 ['Al-Farouq Aminu']
# 1008 ['Kevin Knox']
# 1009 ['C.J. Wilcox']
# 1010 ['Garrett Temple']
# 1011 ['Lucas Nogueira']
# 1012 ['Elias Harris']
# 1013 ['Sam Young']
# 1014 ['Hilton Armstrong']
# 1015 ['Thon Maker']
# 1016 ['Omari Johnson']
# 1017 ['Josh Childress']
# 1018 ['Kareem Rush']
# 1019 ['Vander Blue']
# 1020 ['Antawn Jamison']
# 1021 ['Greg Monroe']
# 1022 ["J.J. O'Brien"]
# 1023 ['Chinanu Onuaku']
# 1024 ['Pierre Jackson']
# 1025 ['JaMychal Green']
# 1026 ['Salah Mejri']
# 1027 ['Maurice Ager']
# 1028 ['Mikki Moore']
# 1029 ['Nik Stauskas']
# 1030 ['Quinn Cook']
# 1031 ['Carrick Felix']
# 1032 ['Darren Collison']
# 1033 ['Sean Williams']
# 1034 ['James Nunnally']
# 1035 ['Willie Cauley-Stein']
# 1036 ['Daniel Gibson']
# 1037 ['Iman Shumpert']
# 1038 ['Chris Babb']
# 1039 ['Udonis Haslem']
# 1040 ['Randolph Morris']
# 1041 ['Trey Gilder']
# 1042 ['Kwame Brown']
# 1043 ['Jameer Nelson']
# 1044 ['Ike Anigbogu']
# 1045 ['Morris Almond']
# 1046 ['Quincy Acy']
# 1047 ['Linas Kleiza']
# 1048 ['Paul Pierce']
# 1049 ['Joel Freeland']
# 1051 ['Anthony Parker']
# 1052 ['Terrence Williams']
# 1053 ['Kyrylo Fesenko']
# 1054 ['James Webb']
# 1055 ['Chris Johnson']
# 1056 ['Carl Landry']
# 1057 ['Joffrey Lauvergne']
# 1058 ['Jamaal Magloire']
# 1059 ['Chris Douglas-Roberts']
# 1060 ['Justin Anderson']
# 1061 ['Shabazz Napier']
# 1062 ['Jason Hart']
# 1063 ['Devin Brown']
# 1064 ['Chris Andersen']
# 1065 ['Fabricio Oberto']
# 1066 ['Eddie House']
# 1067 ['Sean Kilpatrick']
# 1068 ['A.J. Hammons']
# 1069 ['Kevin Ollie']
# 1070 ['Bogdan Bogdanović']
# 1071 ["Shaquille O'Neal"]
# 1072 ['Markieff Morris']
# 1073 ['Andre Ingram']
# 1074 ['Sam Dekker']
# 1075 ['Anthony Johnson']
# 1076 ['Okaro White']
# 1077 ['Marcus Morris']
# 1078 ['Nicolas Batum']
# 1079 ['Damien Inglis']
# 1080 ['OG Anunoby']
# 1081 ['Nolan Smith']
# 1082 ['LeBron James']
# 1083 ['Ivan Rabb']
# 1084 ['Tracy McGrady']
# 1085 ['Quentin Richardson']
# 1086 ['Fab Melo']
# 1087 ['Cory Jefferson']
# 1088 ['Ben McLemore']
# 1089 ['Jabari Bird']
# 1090 ['Nikola Peković']
# 1091 ['Georgios Papagiannis']
# 1092 ['Kris Joseph']
# 1093 ['Ramon Sessions']
# 1094 ['Luke Zeller']
# 1095 ['Devin Harris']
# 1096 ['Drew Gooden']
# 1097 ['Jon Leuer']
# 1098 ['Briante Weber']
# 1099 ['Malik Monk']
# 1101 ['Trey Thompkins']
# 1102 ['Markelle Fultz']
# 1103 ['Bonzie Colson']
# 1104 ['Nikola Jokić']
# 1105 ['Kostas Antetokounmpo']
# 1106 ['Andrew White']
# 1107 ['Brandan Wright']
# 1108 ['Pape Sy']
# 1109 ['DeAndre Liggins']
# 1110 ['Malik Allen']
# 1111 ['Antonius Cleveland']
# 1112 ['Shaquille Harrison']
# 1113 ['Elliot Williams']
# 1114 ['James Singleton']
# 1115 ['Chasson Randle']
# 1116 ['Julian Wright']
# 1117 ['Gary Trent']
# 1118 ['John Collins']
# 1119 ['Shane Edwards']
# 1120 ['DeSagana Diop']
# 1121 ['Shane Battier']
# 1122 ['Justin Dentmon']
# 1123 ['Cameron Payne']
# 1124 ['Michael Gbinije']
# 1125 ['Perry Jones']
# 1126 ['Thanasis Antetokounmpo']
# 1127 ['Othello Hunter']
# 1128 ['Michael Redd']
# 1129 ['Jarell Eddie']
# 1130 ['Marvin Bagley']
# 1131 ['J.R. Giddens']
# 1132 ['Travis Outlaw']
# 1133 ['Ekpe Udoh']
# 1134 ['Bruno Caboclo']
# 1135 ['Monta Ellis']
# 1136 ['Robbie Hummel']
# 1137 ['Wesley Iwundu']
# 1138 ['Alec Peters']
# 1139 ['Alando Tucker']
# 1140 ['Jeffery Taylor']
# 1141 ['Brandon Davies']
# 1142 ['Aaron Gordon']
# 1143 ['Trey Lyles']
# 1144 ['Paul George']
# 1145 ['Nate Wolters']
# 1146 ['Pat Connaughton']
# 1147 ['Omari Spellman']
# 1148 ['Diante Garrett']
# 1149 ['Dwight Buycks']
# 1151 ['Jordan Sibert']
# 1152 ['Alonzo Gee']
# 1153 ['Nick Collison']
# 1154 ['Arinze Onuaku']
# 1155 ['Dionte Christmas']
# 1156 ['Reggie Jackson']
# 1157 ['Luc Mbah a Moute']
# 1158 ['Luigi Datome']
# 1159 ['Jack Cooley']
# 1160 ['Jamaal Franklin']
# 1161 ['Tyler Johnson']
# 1162 ['Pero Antić']
# 1163 ['Amir Johnson']
# 1164 ['Chris Johnson']
# 1165 ['Kyle Wiltjer']
# 1166 ['Álex Abrines']
# 1167 ['Rodney Stuckey']
# 1168 ['Wayne Ellington']
# 1169 ['Marcus Cousin']
# 1170 ['Gary Harris']
# 1171 ['Emmanuel Mudiay']
# 1172 ['Terrence Ross']
# 1173 ['Tony Parker']
# 1174 ['Eddy Curry']
# 1175 ['James Harden']
# 1176 ['Trevon Duval']
# 1177 ['Langston Galloway']
# 1178 ['Darrun Hilliard']
# 1179 ['Aaron Jackson']
# 1180 ['Marcus Derrickson']
# 1181 ['Anderson Varejão']
# 1182 ['Jarron Collins']
# 1183 ["Amar'e Stoudemire"]
# 1184 ['Dion Waiters']
# 1185 ['Keith Appling']
# 1186 ['Jerome Dyson']
# 1187 ['Derrick Jones']
# 1188 ['Evan Turner']
# 1189 ['Stephen Zimmerman']
# 1190 ['Kadeem Allen']
# 1191 ['Lou Amundson']
# 1192 ['Gustavo Ayón']
# 1193 ['Stephen Graham']
# 1194 ['Andre Dawkins']
# 1195 ['Brian Cook']
# 1196 ['Ivan Johnson']
# 1197 ['Kosta Koufos']
# 1198 ['Kalin Lucas']
# 1199 ['Christian Eyenga']
# 1201 ['Kentavious Caldwell-Pope']
# 1202 ['Rasho Nesterović']
# 1203 ['Kim English']
# 1204 ['Shawne Williams']
# 1205 ['Anthony Brown']
# 1206 ['Kyle Lowry']
# 1207 ['Josh Okogie']
# 1208 ['Jordan Mickey']
# 1209 ['Isaac Bonga']
# 1210 ['Tyler Honeycutt']
# 1211 ['Elton Brand']
# 1212 ['Oliver Lafayette']
# 1213 ['Peyton Siva']
# 1214 ['Dwyane Wade']
# 1215 ['Xavier Rathan-Mayes']
# 1216 ['Luol Deng']
# 1217 ['Luke Babbitt']
# 1218 ['Cory Joseph']
# 1219 ['Nando De Colo']
# 1220 ['Bryce Dejean-Jones']
# 1221 ['Zach Collins']
# 1222 ['Sindarius Thornwell']
# 1223 ['Kevin Durant']
# 1224 ['Corey Brewer']
# 1225 ['Samuel Dalembert']
# 1226 ['Hamidou Diallo']
# 1227 ['Ryan Kelly']
# 1228 ['Tony Wroten']
# 1229 ['Pau Gasol']
# 1230 ['Kris Humphries']
# 1231 ['Myles Turner']
# 1232 ['Renaldo Balkman']
# 1233 ['Luka Dončić']
# 1234 ['Willy Hernangómez']
# 1235 ['Jason Richardson']
# 1236 ['Ben Moore']
# 1237 ['Keyon Dooling']
# 1238 ['Kenny Thomas']
# CPU times: user 2min 57s, sys: 13.3 s, total: 3min 11s
# Wall time: 1h 55min 40s

# %%
all_season_df.reset_index(inplace=True, drop=True)

# %%
all_season_df.to_csv('Data/all_season.csv')

# %%
with open('players.txt', 'w') as f:
    for player in player_set:
        f.write("%s\n" % str(player))
